# %%
#파일 읽기
from wordcloud import WordCloud
from matplotlib import rc


f = open("영화댓글2.csv", encoding = "utf-8")
text = f.read()
#print(text)
f.close()

rc('font', family = "NanumGothic")

wcloud = WordCloud("./D2Coding.ttf",
                   max_words=100,
                   relative_scaling=0.2).generate(text)


import matplotlib.pyplot as plt

plt.figure(figsize=(7,7))
plt.imshow(wcloud, interpolation = "bilinear")
plt.axis("off")
plt.savefig( 'myfig.png' )
plt.show()

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import pandas as pd
import time

url_base = "https://movie.naver.com/movie/bi/mi/pointWriteFormList.naver?code=134963&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page="
comments = []
for i in range(1,50) :
    url = url_base + str(i)
    page = urlopen(url)
    soup = BeautifulSoup(page, 'html.parser')
    #print(soup.title)

    reviews = soup.find_all("div", class_="score_reple")
    
    for one in reviews :
        comments.append(one.find_all('span')[1].text.strip())
    time.sleep(0.5)
print(comments)



dict_dat = {"영화댓글" : comments}
dat = pd.DataFrame(dict_dat)
dat.to_csv("영화댓글2.csv", index=False)
dat.to_excel("영화댓글2.xlsx",index=False)
# Out:
# ['wche****', '우훌루후후(dngk****)', '유인나연(ssss****)', 'Casofhjkl(kidi****)', '키돌(doon****)', '연인들을 위한 영화가 아니다. 여성관객들을 위한 영화도 아니다. 이 영화는 꿈꾸는 모든 이들을 위한 영화. 인생을 논하는 영화.', '쇼생크 탈출(chri****)', 'fsli****', '운행종료한 놀이공원에 노래가 계속 나오는 것같다.', '재즈가 이토록 설레고 이렇게 슬프다니.라라랜드는 슬픔과 환희의 설레임이다.', 'Joon(chro****)', '슬프기 짝이 없는 상상.', '아이러니컬하게도, 꿈이라는 건 이루고 난 뒤보다 이루기 전까지가 실은 가장 행복했다는 걸, 이루고 난 뒤에야 깨닫는다는 인생의 진실을 가슴 아프게 그리고 아름답게 보여주는 영화', '꿈꾸는하늘(suni****)', '다시 돌아간다면 지금과 달랐을까?', '왤케눈물이나오는지..ㅠㅠ', '서로의 꿈을 돌보아주고 키워가며 각자의 길을 응원하는 최고의 뮤지컬.', '다미엔 차젤레 감독은 관객에게 황홀한 마법을 걸었다. 재즈에 대한 애정을 담아 연출했고 꿈 꾸는 모든 이들을 위한 영화. 롱테이크 오프닝 시퀀스, OST부터 이미 매료되었고 엔딩까지 한 편의 동화 같은 현실 이야기....', '영화 시작부터 깜짝놀랐다. 지금까지 본 음악영화 중에서 최고다.', '거의 마지막쯤에 나왔던 "흐르는대로가자" 라는 대사가 이 영화를 잘 나타내주었던 말인것 같다. 고민되고 힘이들땐 너무 많은 것을 생각하기보다는  내맘이 끌리는 대로 흐르는대로 가자!', '프라이드(only****)', 'sunn****', '초반부는 그냥 음악이 있는 로맨스겠구나 싶었다. 중반 이후로 넘어가면서 무모할것 같은 꿈을 쫓는 그들의 이야기가   꿈을 포기하고  살고 있는  나의 가슴을 때리고 있었다.  아마도 꿈을 쫓고 있거나 포기한 경험을 ...', '아름디운 영화~라이언고슬링 연기 조으다', '어른을 위한 꿈의 동화~시간이 후딱 갔네요.엔딩은 현실로 여운을 남기는..보면 후회하지 않을거임~', '이런영화가 흥행해야 함. 맨날 스타 배우진만 보
 고루해보일수 있겠지만 그렇기때문에더 담백하고 새로운 기분으로 본 영화였어요', '문돌이(kevi****)', '조따 빡쳐서 댓글쓴다. 판도라 알바들 영화 보지도않고 1점줘서 별점 깎고 10점 비추누름국내영화시장 극혐;; 외화 잘될까봐 부들부들 덜덜떨면서 별점이나 깎고 이딴짓 몇년하고도 지겹지도 않나.. 창피하다 창피해 이러니...', '어썸(urid****)', 'eatemotgre(yona****)', 'sequoia(eme1****)', '정말 최고의영화다80년대 감성에내용도.노래도긴영화임에도 결코 눈을 뗄 수 없는 영화였다', '인생 영화 또 하나 탄생. 보고 나서 여운이 몇날 며칠은 갈 것 같은 영화. 마지막 라이언 고슬링과 엠마스톤의 눈빛이 모든 걸 말해주는.. 영화의 내용과 색감 음악 까지 완벽하게 어우러져서 보는 내내 힐링 되고 보고...', '내 인생작이라 할만큼 재밌게봤음', '남친있는 상태에서 남자주인공으로 환승 남주 꿈 존중하는 듯 하더니 은근슬적 압박줘서 남주가 하기싫은 일하게 되는데 성공하고 바쁘니 싸우고 집나옴 결국 남주가 여자주인공 꿈 이루게 도와줬는데 5년후 꿈이루고 돈많은 딴...', '어떤 노래건 어색함이 없었던 음악영화. 한 해를 마무리하는 영화로 충분합니다.', '아우치(vhfh****)', '영화 영상미 음악은 좋았지만 스토리는 부진특히 극중 미아는 마음이 너무 헤퍼보인다. 첫 남친에게서 남주로 갈아타는 것도 바람난거고 주인공 덕분에 성공한건데 감사의 마음도 너무 적어보이고 인성이 별로다.성공하고 남자를...', '뭐가 재밌다는 건지..여자 주인공 왤케 의리 없는지 이해 안 감..음악이랑 춤은 좋지만 스토리 라인이 너무 빈약;;;뮤직 비디오로 따로 편집해서 보면 좋을 듯합니다.와이프랑 중간에 졸기까지..이런 류 좋아하시는 분 ...', '스피릿(spy_****)', '어리버리(cos_****)', '처음에는 당황, 중간에는 만족, 끝에는 헐...흑흑 눈물이 나와버린 영화.', '저랑은 안맞는영화인것같네요', '어.... 왜 이게 인생영화라는건지 1도 모르겠어영ㅠ  노래도 좋긴한데 전체적으로 쫌 지겨운느낌..', '제스타일의영화가아니였습니다', '어지러운 시국에 이런 일탈이라도 필요하다', '너무나도 평점이 좋은 영화여서 너무 기대를했지만 이렇게 지루하고 재미없는 영화는 처음이였다.중간에 영화를 그만보고 나가고 싶다는 생각을 하였고 영화보는내내 의자가 불편하고 딱딱한적은 처음이였다.전체적으로 너무 재미없...', '저만 재미없나봐요 ;;', '나는 개인적으로 별로 재미 없었어요....', '10번 보면 10번 모두 다른 감동을 느낄 수 있을 거 같네요. 그런 의미에서 또 보러갑니다', '대법관(rjaa****)', 'shel****', '김수진(ksj0****)', '31정승호(seun****)', 'Inss(leej****)', '평점보고  이 영화를  기대하며 보았지만  내용은  실망하기  딱  좋았고,  엔딩이 아주 허무하기  짝이  없었다.  중독성  있는  노래는 좋았지만  모든것 ...
